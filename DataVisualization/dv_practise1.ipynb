# %% [markdown]
# <a href="https://colab.research.google.com/github/kjeyaram-orcl/DataScience/blob/main/DataVisualization/dv_practise1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install seaborn

# %% [markdown]
# # Scatter Plot
# A scatter plot is used to visualize the relationship between two continuous variables

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt


ds = pd.read_csv('/content/athlete_events.csv')
#print(ds.head(5))
sns.scatterplot(x='Weight',y='Height', hue='Sex', size='Age', data =ds)
plt.title("Relationship between Weight and Height")
plt.show()
